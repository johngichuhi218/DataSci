# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer

data_path = '/content/maitenance_record_data.csv'
df = pd.read_csv(data_path)

# explore dataset
print(df.head())


# datetime format
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# Status is a target variable (Normal/Faulty)
le = LabelEncoder()
df['Status'] = le.fit_transform(df['Status'])

# Feature engineering for timestamps
df['HourOfDay'] = df['Timestamp'].dt.hour


# Handling missing values
imputer = SimpleImputer(strategy='mean')
df['Temperature'] = imputer.fit_transform(df[['Temperature']])
df['Pressure'] = imputer.fit_transform(df[['Pressure']])

# features and target variables
features = ['Temperature', 'Pressure', 'HourOfDay']
target = 'Status'

# training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)

# Train a machine learning model
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
classification_report_result = classification_report(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print("Classification Report:\n", classification_report_result)

# %%
df.head()
# Out:
#             Timestamp  Temperature    Pressure  Status  HourOfDay
# 0 2019-01-01 00:00:00    33.973713  966.241086       1          0
# 1 2019-01-01 00:01:00    28.893886  992.774066       1          0
# 2 2019-01-01 00:02:00    35.181508  960.379004       0          0
# 3 2019-01-01 00:03:00    42.184239  984.601924       1          0
# 4 2019-01-01 00:04:00    28.126773  905.319267       1          0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_97['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_98['Temperature'].plot(kind='hist', bins=20, title='Temperature')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_99['Pressure'].plot(kind='hist', bins=20, title='Pressure')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_100['Status'].plot(kind='hist', bins=20, title='Status')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_101.plot(kind='scatter', x='index', y='Temperature', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_102.plot(kind='scatter', x='Temperature', y='Pressure', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_103.plot(kind='scatter', x='Pressure', y='Status', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Timestamp']
#   ys = series['Temperature']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_104.sort_values('Timestamp', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Timestamp')
# _ = plt.ylabel('Temperature')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Timestamp']
#   ys = series['Pressure']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_105.sort_values('Timestamp', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Timestamp')
# _ = plt.ylabel('Pressure')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Timestamp']
#   ys = series['Status']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_106.sort_values('Timestamp', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Timestamp')
# _ = plt.ylabel('Status')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Timestamp']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Timestamp'}, axis=1)
#               .sort_values('Timestamp', ascending=True))
#   xs = counted['Timestamp']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_107.sort_values('Timestamp', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Timestamp')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_108['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_109['Temperature'].plot(kind='line', figsize=(8, 4), title='Temperature')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_110['Pressure'].plot(kind='line', figsize=(8, 4), title='Pressure')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_111['Status'].plot(kind='line', figsize=(8, 4), title='Status')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df.describe()
# Out:
#        Temperature     Pressure       Status    HourOfDay
# count  2000.000000  2000.000000  2000.000000  2000.000000
# mean     30.360673   999.677875     0.795500     9.450000
# std       7.907725    50.267703     0.403437     6.882673
# min       4.069861   849.024392     0.000000     0.000000
# 25%      25.018705   964.543702     1.000000     4.000000
# 50%      30.357533   999.997335     1.000000     8.000000
# 75%      35.463821  1033.277184     1.000000    15.000000
# max      60.821852  1196.311885     1.000000    23.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_112['Temperature'].plot(kind='hist', bins=20, title='Temperature')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_113['Pressure'].plot(kind='hist', bins=20, title='Pressure')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_114['Status'].plot(kind='hist', bins=20, title='Status')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_115['HourOfDay'].plot(kind='hist', bins=20, title='HourOfDay')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_116.groupby('index').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_117.plot(kind='scatter', x='Temperature', y='Pressure', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_118.plot(kind='scatter', x='Pressure', y='Status', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_119.plot(kind='scatter', x='Status', y='HourOfDay', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_120['Temperature'].plot(kind='line', figsize=(8, 4), title='Temperature')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_121['Pressure'].plot(kind='line', figsize=(8, 4), title='Pressure')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_122['Status'].plot(kind='line', figsize=(8, 4), title='Status')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_123['HourOfDay'].plot(kind='line', figsize=(8, 4), title='HourOfDay')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_124['index'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_124, x='Temperature', y='index', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_125['index'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_125, x='Pressure', y='index', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_126['index'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_126, x='Status', y='index', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_127['index'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_127, x='HourOfDay', y='index', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
df.tail()
# Out:
#                Timestamp  Temperature     Pressure  Status  HourOfDay
# 1995 2019-01-02 09:15:00    38.561202  1001.422879       1          9
# 1996 2019-01-02 09:16:00    29.787830   896.109409       1          9
# 1997 2019-01-02 09:17:00    22.945003   983.985110       1          9
# 1998 2019-01-02 09:18:00    28.695464  1082.168908       1          9
# 1999 2019-01-02 09:19:00    24.040779  1018.032395       1          9
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_128['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_129['Temperature'].plot(kind='hist', bins=20, title='Temperature')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_130['Pressure'].plot(kind='hist', bins=20, title='Pressure')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_131.plot(kind='scatter', x='index', y='Temperature', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_132.plot(kind='scatter', x='Temperature', y='Pressure', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Timestamp']
#   ys = series['Temperature']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_133.sort_values('Timestamp', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Timestamp')
# _ = plt.ylabel('Temperature')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Timestamp']
#   ys = series['Pressure']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_134.sort_values('Timestamp', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Timestamp')
# _ = plt.ylabel('Pressure')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Timestamp']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Timestamp'}, axis=1)
#               .sort_values('Timestamp', ascending=True))
#   xs = counted['Timestamp']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_135.sort_values('Timestamp', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Timestamp')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['Temperature']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_136.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('Temperature')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_137['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_138['Temperature'].plot(kind='line', figsize=(8, 4), title='Temperature')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_139['Pressure'].plot(kind='line', figsize=(8, 4), title='Pressure')
# plt.gca().spines[['top', 'right']].set_visible(False)
